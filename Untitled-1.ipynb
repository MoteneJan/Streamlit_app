# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import MeanIoU

# Re-define dice_loss
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# Load the fine-tuned model
#model_path = 'path_to/final_model_resunet_finetuned_lr_reduced.h5'
model_path = 'final_model_resunet_finetuned_lr_reduced.h5'
model = load_model(model_path, custom_objects={'dice_loss': dice_loss, 'MeanIoU': MeanIoU})

# Print the model summary
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# ...

# %%
import h5py

model_path = 'final_model_resunet_finetuned_lr_reduced.h5'

with h5py.File(model_path, "r") as f:
    print("Keys are: ", list(f.keys()))
# Out:
# Keys are:  ['model_weights', 'optimizer_weights']

# %%
weights_path = "final_model_resunet_finetuned_lr_reduced.h5"

# Load weights by matching layer names and skipping mismatches
try:
    model.load_weights(weights_path, by_name=True, skip_mismatch=True)
    print("Weights loaded successfully by matching layer names!")
except Exception as e:
    print(f"Error loading weights: {e}")
# Out:
# Weights loaded successfully by matching layer names!
# c:\Users\moten\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:513: UserWarning: Skipping loading weights for layer #9 (named conv2d_4)due to mismatch in shape for weight conv2d_4/kernel. Weight expects shape (3, 3, 3, 64). Received saved weight with shape (3, 3, 32, 64)
#   _set_weights(
# c:\Users\moten\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:513: UserWarning: Skipping loading weights for layer #11 (named conv2d_5)due to mismatch in shape for weight conv2d_5/kernel. Weight expects shape (3, 3, 64, 128). Received saved weight with shape (3, 3, 64, 64)
#   _set_weights(
# c:\Users\moten\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:513: UserWarning: Skipping loading weights for layer #11 (named conv2d_5)due to mismatch in shape for weight conv2d_5/bias. Weight expects shape (128,). Received saved weight with shape (64,)
#   _set_weights(
# ...

# %%
import h5py

weights_path = "final_model_resunet_finetuned_lr_reduced.h5"
with h5py.File(weights_path, 'r') as f:
    print("Keys in the weights file:", list(f.keys()))
    if 'model_weights' in f:
        print("Model weights layers:", list(f['model_weights'].keys()))
# Out:
# Keys in the weights file: ['model_weights', 'optimizer_weights']
# Model weights layers: ['activation', 'activation_1', 'activation_2', 'activation_3', 'activation_4', 'add', 'add_1', 'add_2', 'add_3', 'add_4', 'batch_normalization', 'batch_normalization_1', 'batch_normalization_2', 'batch_normalization_3', 'batch_normalization_4', 'batch_normalization_5', 'batch_normalization_6', 'batch_normalization_7', 'batch_normalization_8', 'batch_normalization_9', 'concatenate', 'concatenate_1', 'conv2d', 'conv2d_1', 'conv2d_10', 'conv2d_11', 'conv2d_12', 'conv2d_13', 'conv2d_14', 'conv2d_15', 'conv2d_2', 'conv2d_3', 'conv2d_4', 'conv2d_5', 'conv2d_6', 'conv2d_7', 'conv2d_8', 'conv2d_9', 'conv2d_transpose', 'conv2d_transpose_1', 'dropout', 'input_layer', 'max_pooling2d', 'max_pooling2d_1', 'top_level_model_weights']

# %%
# Unfreeze base model if needed for fine-tuning
model.layers[1].trainable = True  # Assuming DenseNet201 is the second layer

# Recompile the model after making changes
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# Train the model on your dataset
model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=10, batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 10
#       5 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
#       6               loss='binary_crossentropy',
#       7               metrics=['accuracy'])
#       9 # Train the model on your dataset
# ---> 10 model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=10, batch_size=16)
#
# NameError: name 'train_data' is not defined

# %%
def build_resunet(input_shape):
    from tensorflow.keras import layers, models

    inputs = layers.Input(shape=input_shape)
    # Add layers for ResUNet
    x = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.UpSampling2D((2, 2))(x)
    outputs = layers.Conv2D(1, (1, 1), activation="sigmoid")(x)

    model = models.Model(inputs, outputs)
    return model

# Build the model
model = build_resunet(input_shape=(64, 64, 3))

# Load weights
model.load_weights(weights_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 19
#      16 model = build_resunet(input_shape=(64, 64, 3))
#      18 # Load weights
# ---> 19 model.load_weights(weights_path)
#
# File c:\Users\moten\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\moten\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:357, in load_weights_from_hdf5_group(f, model)
#     355 layer_names = filtered_layer_names
#     356 if len(layer_names) != len(filtered_layers):
# ...

# %%
import numpy as np

# Example input format expected by the model
input_data = np.random.rand(1, 256, 256, 3)  # Adjust shape as per your model's input layer
predictions = model.predict(input_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step

# %%
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# %%
from tensorflow.keras.models import load_model

# Validate model file
try:
    model = load_model(
        'final_model_resunet_finetuned_lr_reduced.h5',
        custom_objects={'dice_loss': dice_loss, 'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=2)}
    )
    print("Model loaded successfully!")
    print(model.summary())
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# Custom dice loss function
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# Load the model
try:
    model = load_model(
        'final_model_resunet_finetuned_lr_reduced.h5',
        custom_objects={'dice_loss': dice_loss, 'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=2)}
    )
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")

# Test with random input
input_data = np.random.rand(1, 256, 256, 3).astype('float32')  # Adjust shape as needed
try:
    predictions = model.predict(input_data)
    print("Prediction successful!")
    print(predictions)
except Exception as e:
    print(f"Error during prediction: {e}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step
# Prediction successful!
# [[[[4.5706927e-15]
#    [1.6508519e-11]
#    [1.6250069e-15]
#    ...
#    [4.5089559e-14]
#    [2.2048643e-09]
#    [2.2277713e-17]]
#
#   [[8.7210265e-12]
#    [6.5687011e-08]
#    [3.9050607e-09]
#    ...
#    [2.6242122e-01]
#    [9.9999595e-01]
#    [5.5628635e-13]]
#
#   [[8.1018859e-18]
#    [1.4860071e-09]
#    [9.8767904e-15]
#    ...
#    [4.1756437e-21]
#    [1.2497148e-08]
#    [5.8484082e-13]]
#
#   ...
#
#   [[9.6873744e-24]
#    [1.2084142e-10]
#    [1.1941130e-20]
#    ...
#    [3.8184311e-16]
#    [9.6286098e-14]
#    [1.3159252e-15]]
#
#   [[5.8074044e-20]
#    [4.6651529e-08]
#    [1.1753059e-17]
#    ...
#    [9.8837875e-11]
#    [2.9413911e-06]
#    [2.3517517e-14]]
#
#   [[6.0251926e-20]
# ...

# %%
# Get predictions
predictions = model.predict(input_data)

# Check if the output is a dictionary
if isinstance(predictions, dict):
    print("Keys in model output:", predictions.keys())
    # Access using the correct key
    desired_output = predictions["desired_key"]
else:
    # Handle as a single tensor or array
    desired_output = predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step

# %%
# Check model input shape
print("Model input shape:", model.input_shape)

# Check model output shape
print("Model output shape:", model.output_shape)
# Out:
# Model input shape: (None, 256, 256, 3)
# Model output shape: (None, 256, 256, 1)

# %%
from tensorflow.keras.models import load_model

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# Load model with custom objects
model = load_model(
    'final_model_resunet_finetuned_lr_reduced.h5',
    custom_objects={'dice_loss': dice_loss, 'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=2)}
)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
from tensorflow.keras.models import load_model

# Load model with custom objects
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

model = load_model(
    'final_model_resunet_finetuned_lr_reduced.h5',
    custom_objects={'dice_loss': dice_loss, 'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=2)}
)

# Simulate valid input
input_data = np.random.rand(1, 256, 256, 3).astype('float32')

# Predict and print the output
try:
    predictions = model.predict(input_data)
    print("Prediction successful!")
    print(predictions)
except Exception as e:
    print(f"Error during prediction: {e}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# Prediction successful!
# [[[[2.70367898e-15]
#    [2.78995746e-14]
#    [1.44547985e-14]
#    ...
#    [1.02611321e-18]
#    [3.12743278e-16]
#    [2.45888950e-18]]
#
#   [[4.67848871e-10]
#    [2.18000519e-03]
#    [1.92023575e-09]
#    ...
#    [5.62878677e-15]
#    [6.94482765e-07]
#    [3.91682875e-14]]
#
#   [[3.38663125e-11]
#    [3.11816839e-05]
#    [3.35406006e-14]
#    ...
#    [2.64108678e-17]
#    [8.29705582e-10]
#    [6.01583287e-16]]
#
#   ...
#
#   [[2.59475044e-17]
#    [5.01724550e-14]
#    [7.25161018e-23]
#    ...
#    [1.82692349e-13]
#    [8.47618891e-14]
#    [6.30634029e-17]]
#
#   [[3.01872172e-19]
#    [3.73383643e-15]
#    [7.39749754e-20]
#    ...
#    [4.05909091e-11]
#    [8.69100205e-08]
#    [3.68217875e-16]]
#
#   [[1.35409894e-20]
# ...

# %%
model.save('final_model.h5')
print("Model save successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model save successfully

# %%
import matplotlib.pyplot as plt

sizes = [15, 30, 45, 10]
labels = ["A","B","C","D"]

plt.pie(sizes, labels=labels, autopct="%1.1f%%")
circle = plt.Circle((0,0), 0.8, color="White")
plt.gca().add_artist(circle)
plt.title("Donut Chart")
plt.show()
